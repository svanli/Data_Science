# %% [markdown]
# # Essential Math for Data Science

# %% [markdown]
# ## 1. Basic Math and Calculus Review

# %% [markdown]
# ### Order of Operations

# %%
my_value = 2 * (3 + 2)**2 / 5 - 4
print(my_value)
# Out:
# 6.0

# %%
my_value = 2 * ((3 + 2)**2 / 5) - 4
print(my_value)
# Out:
# 6.0

# %% [markdown]
# ### Variables

# %%
x = int(input('Please input a number\n'))

product = 3 * x

print(product)
# Out:
# Please input a number
#  2
# 6

# %%
beta = 1.75
theta = 30.0

# %%
x1 = 3  # or x_1 = 3
x2 = 10 # or x_2 = 10
x3 = 44 # or x_3 = 44

# %% [markdown]
# ### Functions

# %%
def f(x):
    return 2 * x + 1

x_values = [0, 1, 2, 3]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %%
from sympy import *

# %%
x = symbols('x')
f = 2*x + 1
plot(f)

# %%
a = symbols('a')

f_2 = 41*a**2 - 20*a + 2+a**3
plot(f_2)

# %%
x = symbols('x')
f = x**2 + 1
plot(f)

# %%
from sympy.plotting import plot3d

# %%
x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %% [markdown]
# ### Summations

# %%
summation = sum(2*i for i in range(1, 6))
print(summation)
# Out:
# 30

# %%
x = [1, 4, 6, 2]
n = len(x)

summation = sum(10*x[i] for i in range(0, n))
print(summation)
# Out:
# 130

# %%
i, n = symbols('i n')
summation = Sum(2*i, (i, 1, n)) # Use Sum class. Summation of 2*i. i iterates from 1 to n.

up_to_5 = summation.subs(n, 5)  # Substitute symbol n with 5.
print(up_to_5.doit())           # To execute the expression use .doit()
# Out:
# 30

# %%
summation.subs(n, 5)
# Out:
# Sum(2*i, (i, 1, 5))

# %% [markdown]
# ### Exponents

# %%
x = symbols('x')
expr = x**2 / x**5
print(expr)
# Out:
# x**(-3)

# %%
((8**3)**2)
# Out:
# 262144

# %%
8*8*8*8*8*8
# Out:
# 262144

# %%
8**(2/3)
# Out:
# 3.9999999999999996

# %%
from math import log

# %%
x = log(8, 2)
print(x)
# Out:
# 3.0

# %%
x_1 = log(8, )
print(x_1)
# Out:
# 2.0794415416798357
