# %% [markdown]
# # Notes (03)

# %%
import numpy as np
# from scipy import sparse
from scipy.sparse import lil_matrix, csr_matrix

# %%
try: 
    import plmb
except ImportError:
    # !pip install pmlb

# %% [markdown]
# # 03. Datasets and Benchmark

# %%
import pmlb

# %%
pmlb.dataset_names
# Out:
# ['GAMETES_Epistasis_2_Way_1000atts_0.4H_EDM_1_EDM_1_1',
#  'GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1',
#  'GAMETES_Epistasis_2_Way_20atts_0.4H_EDM_1_1',
#  'GAMETES_Epistasis_3_Way_20atts_0.2H_EDM_1_1',
#  'GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM_2_001',
#  'GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM_2_001',
#  'Hill_Valley_with_noise',
#  'Hill_Valley_without_noise',
#  'adult',
#  'agaricus_lepiota',
#  'allbp',
#  'allhyper',
#  'allhypo',
#  'allrep',
#  'analcatdata_aids',
#  'analcatdata_asbestos',
#  'analcatdata_authorship',
#  'analcatdata_bankruptcy',
#  'analcatdata_boxing1',
#  'analcatdata_boxing2',
#  'analcatdata_creditscore',
#  'analcatdata_cyyoung8092',
#  'analcatdata_cyyoung9302',
#  'analcatdata_dmft',
#  'analcatdata_fraud',
#  'analcatdata_germangss',
#  'analcatdata_happiness',
#  'analcatdata_japansolvent',
#  'analcatdata_lawsuit',
#  'ann_thyroid',
#  'appendicitis',
#  'australian',
#  'auto',
#  'backache',
#  'balance_scale',
# ...

# %%
print('All datasets in PMLB:')
print('—————————————————————')
print('\n')

for i, set in enumerate(pmlb.dataset_names):
    print(f'{i+1}. {set}')
# Out:
# All datasets in PMLB:
# —————————————————————
#
#
# 1. GAMETES_Epistasis_2_Way_1000atts_0.4H_EDM_1_EDM_1_1
# 2. GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1
# 3. GAMETES_Epistasis_2_Way_20atts_0.4H_EDM_1_1
# 4. GAMETES_Epistasis_3_Way_20atts_0.2H_EDM_1_1
# 5. GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM_2_001
# 6. GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM_2_001
# 7. Hill_Valley_with_noise
# 8. Hill_Valley_without_noise
# 9. adult
# 10. agaricus_lepiota
# 11. allbp
# 12. allhyper
# 13. allhypo
# 14. allrep
# 15. analcatdata_aids
# 16. analcatdata_asbestos
# 17. analcatdata_authorship
# 18. analcatdata_bankruptcy
# 19. analcatdata_boxing1
# 20. analcatdata_boxing2
# 21. analcatdata_creditscore
# 22. analcatdata_cyyoung8092
# 23. analcatdata_cyyoung9302
# 24. analcatdata_dmft
# 25. analcatdata_fraud
# 26. analcatdata_germangss
# 27. analcatdata_happiness
# 28. analcatdata_japansolvent
# 29. analcatdata_lawsuit
# 30. ann_thyroid
# 31. appendicitis
# 32. australian
# ...

# %%
from pmlb import fetch_data

# %%
banana = fetch_data('banana')

# %%
banana.head()
# Out:
#      At1    At2  target
# 0  1.140 -0.114       0
# 1 -1.520 -1.150       1
# 2 -1.050  0.720       0
# 3 -0.916  0.397       1
# 4 -1.090  0.437       1

# %%
adult = fetch_data('adult')

# %%
adult.head(20)
# Out:
#      age  workclass    fnlwgt  education  education-num  marital-status  \
# 0   39.0          7   77516.0          9           13.0               4
# 1   50.0          6   83311.0          9           13.0               2
# 2   38.0          4  215646.0         11            9.0               0
# 3   53.0          4  234721.0          1            7.0               2
# 4   28.0          4  338409.0          9           13.0               2
# 5   37.0          4  284582.0         12           14.0               2
# 6   49.0          4  160187.0          6            5.0               3
# 7   52.0          6  209642.0         11            9.0               2
# 8   31.0          4   45781.0         12           14.0               4
# 9   42.0          4  159449.0          9           13.0               2
# 10  37.0          4  280464.0         15           10.0               2
# 11  30.0          7  141297.0          9           13.0               2
# ...

# %%
adult
# Out:
#         age  workclass    fnlwgt  education  education-num  marital-status  \
# 0      39.0          7   77516.0          9           13.0               4
# 1      50.0          6   83311.0          9           13.0               2
# 2      38.0          4  215646.0         11            9.0               0
# 3      53.0          4  234721.0          1            7.0               2
# 4      28.0          4  338409.0          9           13.0               2
# ...     ...        ...       ...        ...            ...             ...
# 48837  39.0          4  215419.0          9           13.0               0
# 48838  64.0          0  321403.0         11            9.0               6
# 48839  38.0          4  374983.0          9           13.0               2
# 48840  44.0          4   83891.0          9           13.0               0
# 48841  35.0          5  182148.0          9           13.0               2
#
# ...

# %%
banana_X, banana_y = fetch_data('banana', return_X_y=True)

print(banana_X, '\n')
print(banana_y)
# Out:
# [[ 1.14  -0.114]
#  [-1.52  -1.15 ]
#  [-1.05   0.72 ]
#  ...
#  [ 2.64   1.14 ]
#  [ 0.769  0.772]
#  [-0.255 -0.142]]
#
# [0 1 0 ... 1 0 1]

# %%
banana_X, banana_y = fetch_data('banana', return_X_y=True, local_cache_dir='./data')

print(banana_X, '\n')
print(banana_y)
# Out:
# [[ 1.14  -0.114]
#  [-1.52  -1.15 ]
#  [-1.05   0.72 ]
#  ...
#  [ 2.64   1.14 ]
#  [ 0.769  0.772]
#  [-0.255 -0.142]]
#
# [0 1 0 ... 1 0 1]

# %%
bc_1 = fetch_data('breast_cancer', local_cache_dir='./data')
bc_1.head(30)
# Out:
#     age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0     2          2           2          0          2          3       1
# 1     3          0           2          0          1          1       1
# 2     3          0           6          0          1          2       0
# 3     2          2           6          0          2          3       1
# 4     2          2           5          4          2          2       0
# 5     3          2           4          4          1          2       1
# 6     3          0           7          0          1          3       0
# 7     2          2           1          0          1          2       0
# 8     2          2           0          0          1          2       1
# 9     2          0           7          2          2          2       1
# 10    3          2           4          0          1          2       0
# 11    4          0           2          0          1          2       1
# ...

# %%
bc_2 = fetch_data('breast_cancer', local_cache_dir='')
bc_2.head(30)
# Out:
#     age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0     2          2           2          0          2          3       1
# 1     3          0           2          0          1          1       1
# 2     3          0           6          0          1          2       0
# 3     2          2           6          0          2          3       1
# 4     2          2           5          4          2          2       0
# 5     3          2           4          4          1          2       1
# 6     3          0           7          0          1          3       0
# 7     2          2           1          0          1          2       0
# 8     2          2           0          0          1          2       1
# 9     2          0           7          2          2          2       1
# 10    3          2           4          0          1          2       0
# 11    4          0           2          0          1          2       1
# ...

# %%
from pmlb import fetch_data, classification_dataset_names

for i, classification_dataset in enumerate(classification_dataset_names):
    print(i, classification_dataset)
# Out:
# 0 GAMETES_Epistasis_2_Way_1000atts_0.4H_EDM_1_EDM_1_1
# 1 GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1
# 2 GAMETES_Epistasis_2_Way_20atts_0.4H_EDM_1_1
# 3 GAMETES_Epistasis_3_Way_20atts_0.2H_EDM_1_1
# 4 GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM_2_001
# 5 GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM_2_001
# 6 Hill_Valley_with_noise
# 7 Hill_Valley_without_noise
# 8 adult
# 9 agaricus_lepiota
# 10 allbp
# 11 allhyper
# 12 allhypo
# 13 allrep
# 14 analcatdata_aids
# 15 analcatdata_asbestos
# 16 analcatdata_authorship
# 17 analcatdata_bankruptcy
# 18 analcatdata_boxing1
# 19 analcatdata_boxing2
# 20 analcatdata_creditscore
# 21 analcatdata_cyyoung8092
# 22 analcatdata_cyyoung9302
# 23 analcatdata_dmft
# 24 analcatdata_fraud
# 25 analcatdata_germangss
# 26 analcatdata_happiness
# 27 analcatdata_japansolvent
# 28 analcatdata_lawsuit
# 29 ann_thyroid
# 30 appendicitis
# 31 australian
# 32 auto
# 33 backache
# 34 balance_scale
# 35 biomed
# 36 breast
# 37 breast_cancer
# ...

# %%
analcatdata_creditscore = fetch_data('analcatdata_creditscore')
analcatdata_creditscore
# Out:
#      Age  Income.per.dependent  Monthly.credit.card.exp  Own.home  \
# 0   38.0                  4.52                   124.98         1
# 1   33.0                  2.42                     9.85         0
# 2   34.0                  4.50                    15.00         1
# 3   31.0                  2.54                   137.87         0
# 4   32.0                  9.79                   546.50         1
# ..   ...                   ...                      ...       ...
# 95  22.0                  1.56                     0.00         0
# 96  33.0                  6.00                   474.15         1
# 97  25.0                  3.60                   234.05         0
# 98  26.0                  5.00                   451.20         1
# 99  46.0                  5.50                   251.52         1
#
#     Self.employed  Derogatory.reports  target
# 0               0                   0       1
# 1               0                   0       1
# ...
