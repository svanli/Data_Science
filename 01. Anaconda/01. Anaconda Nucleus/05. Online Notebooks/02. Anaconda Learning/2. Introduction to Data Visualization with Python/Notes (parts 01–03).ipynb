# %% [markdown]
# <h1>Notes (parts 01–03)</h1>

# %%
name = 'John'
print(f'Hello {name}!')
# Out:
# Hello John!

# %% [markdown]
# # 02. How to read a plot

# %%
import matplotlib.pyplot as plt

# %%
figsize = (14, 5)

# %%
print(figsize)
# Out:
# (14, 5)

# %%
fig, ax = plt.subplots(figsize = (5, 3))
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]

# %%
plt.plot(x, y)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('My Plot')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('My Plot')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('My Plot')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('My Plot')

plt.show()

# %%
help(plt.show)
# Out:
# Help on function show in module matplotlib.pyplot:
#
# show(close=None, block=None)
#     Display all open figures.
#
#     Parameters
#     ----------
#     block : bool, optional
#         Whether to wait for all figures to be closed before returning.
#
#         If `True` block and run the GUI main loop until all figure windows
#         are closed.
#
#         If `False` ensure that all figure windows are displayed and return
#         immediately.  In this case, you are responsible for ensuring
#         that the event loop is running to have responsive figures.
#
#         Defaults to True in non-interactive mode and to False in interactive
#         mode (see `.pyplot.isinteractive`).
#
#     See Also
#     --------
#     ion : Enable interactive mode, which shows / updates the figure after
#           every plotting command, so that calling ``show()`` is not necessary.
#     ioff : Disable interactive mode.
# ...

# %%
plt.show?
# Out:
# Signature: plt.show(close=None, block=None)
# Docstring:
# Display all open figures.
#
# Parameters
# ----------
# block : bool, optional
#     Whether to wait for all figures to be closed before returning.
#
#     If `True` block and run the GUI main loop until all figure windows
#     are closed.
#
#     If `False` ensure that all figure windows are displayed and return
#     immediately.  In this case, you are responsible for ensuring
#     that the event loop is running to have responsive figures.
#
#     Defaults to True in non-interactive mode and to False in interactive
#     mode (see `.pyplot.isinteractive`).
#
# See Also
# --------
# ion : Enable interactive mode, which shows / updates the figure after
#       every plotting command, so that calling ``show()`` is not necessary.
# ioff : Disable interactive mode.
# savefig : Save the figure to an image file instead of showing it on screen.
#
# Notes
# -----
# **Saving figures to file and showing a window at the same time**
# ...

# %%
plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

plt.scatter([1, 2, 3, 4], [1, 4, 2, 3])

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('My Plot')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

plt.bar([1, 2, 3, 4], [1, 4, 2, 3])

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('My Plot')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

plt.plot(
    [1, 2, 3, 4], [1, 4, 2, 3], 
    color = 'red', 
    marker = '.',
    linestyle = 'dashed',
    markersize = 5,
    linewidth = 1
)

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('My Plot')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

ax.plot(
    [1, 2, 3, 4], [1, 4, 2, 3], 
    label = 'FY2223',
    color = 'blue', 
    marker = '.',
    markersize = 5,
    linewidth = 1
)

ax.plot(
    [1, 2, 3, 4], [1, 3, 3, 2], 
    label = 'FY2122',
    color = 'grey', 
    marker = '.',
    linestyle = 'dashed',
    markersize = 5,
    linewidth = 1
)

ax.bar(
    [1, 2, 3, 4], [0.3, 0.5, 0.1, 0.4],
    label = 'ABO sales'
)

ax.set_xlabel('Quarter')
ax.set_ylabel('mln €')
ax.set_title('Sales in FY2223 and FY2122')
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 3))

ax.plot(
    [1, 2, 3, 4], [1, 4, 2, 3], 
    label = 'FY2223',
    color = 'blue', 
    marker = '.',
    markersize = 5,
    linewidth = 1
)

ax.plot(
    [1, 2, 3, 4], [1, 3, 3, 2], 
    label = 'FY2122',
    color = 'grey', 
    marker = '.',
    linestyle = 'dashed',
    markersize = 5,
    linewidth = 1
)

ax.set_xlabel('Quarter')
ax.set_ylabel('mln €')
ax.set_title('Sales in FY2223 and FY2122')
ax.legend()

ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20644\3477295980.py in <module>
#      25 ax.legend()
#      26
# ---> 27 ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
#      28
#      29 plt.show()
#
# NameError: name 'ticker' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(
    [1, 2, 3, 4], [1, 4, 2, 3],
    label='FY2223',
    color='blue',
    marker='.',
    markersize=5,
    linewidth=1
)

ax.plot(
    [1, 2, 3, 4], [1, 3, 3, 2],
    label='FY2122',
    color='grey',
    marker='.',
    linestyle='dashed',
    markersize=5,
    linewidth=1
)

ax.set_xlabel('Quarter')
ax.set_ylabel('mln €')
ax.set_title('Sales in FY2223 and FY2122')
ax.legend()

ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

plt.show()

# %% [markdown]
# # 03. How to derive basic insights from data?

# %%
import pandas as pd

# %%
df = pd.read_csv('NYPD_Shooting_Incident_Data__Historic_.csv')

# %%
df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0     228798151  05/27/2021   21:30:00  QUEENS               NaN       105
# 1     137471050  06/27/2014   17:40:00   BRONX               NaN        40
# 2     147998800  11/21/2015   03:56:00  QUEENS               NaN       108
# 3     146837977  10/09/2015   18:30:00   BRONX               NaN        44
# 4      58921844  02/19/2009   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG  ... PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0                    False  ...      NaN       NaN         18-24       M
# ...

# %%
len(df)
# Out:
# 27312

# %%
df.describe()
# Out:
#        INCIDENT_KEY      PRECINCT  JURISDICTION_CODE    X_COORD_CD  \
# count  2.731200e+04  27312.000000       27310.000000  2.731200e+04
# mean   1.208605e+08     65.635362           0.326913  1.009449e+06
# std    7.341286e+07     27.305705           0.737743  1.837783e+04
# min    9.953245e+06      1.000000           0.000000  9.149281e+05
# 25%    6.386088e+07     44.000000           0.000000  1.000029e+06
# 50%    9.037222e+07     68.000000           0.000000  1.007731e+06
# 75%    1.888102e+08     81.000000           0.000000  1.016838e+06
# max    2.611902e+08    123.000000           2.000000  1.066815e+06
#
#           Y_COORD_CD      Latitude     Longitude
# count   27312.000000  27302.000000  27302.000000
# mean   208127.401608     40.737892    -73.909051
# std     31886.377757      0.087525      0.066272
# min    125756.718750     40.511586    -74.249303
# 25%    182834.335938     40.668481    -73.943027
# 50%    194486.570312     40.700318    -73.915221
# ...

# %%
df.columns
# Out:
# Index(['INCIDENT_KEY', 'OCCUR_DATE', 'OCCUR_TIME', 'BORO', 'LOC_OF_OCCUR_DESC',
#        'PRECINCT', 'JURISDICTION_CODE', 'LOC_CLASSFCTN_DESC', 'LOCATION_DESC',
#        'STATISTICAL_MURDER_FLAG', 'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE',
#        'VIC_AGE_GROUP', 'VIC_SEX', 'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD',
#        'Latitude', 'Longitude', 'Lon_Lat'],
#       dtype='object')

# %%
df.BORO
# Out:
# 0           QUEENS
# 1            BRONX
# 2           QUEENS
# 3            BRONX
# 4            BRONX
#            ...
# 27307        BRONX
# 27308    MANHATTAN
# 27309    MANHATTAN
# 27310        BRONX
# 27311        BRONX
# Name: BORO, Length: 27312, dtype: object

# %%
df['BORO']
# Out:
# 0           QUEENS
# 1            BRONX
# 2           QUEENS
# 3            BRONX
# 4            BRONX
#            ...
# 27307        BRONX
# 27308    MANHATTAN
# 27309    MANHATTAN
# 27310        BRONX
# 27311        BRONX
# Name: BORO, Length: 27312, dtype: object

# %%
df.INCIDENT_KEY.mean()
# Out:
# 120860535.80521382

# %%
df.INCIDENT_KEY.std()
# Out:
# 73412858.84094127

# %%
df.BORO.value_counts()
# Out:
# BROOKLYN         10933
# BRONX             7937
# QUEENS            4094
# MANHATTAN         3572
# STATEN ISLAND      776
# Name: BORO, dtype: int64

# %%
df.PRECINCT.value_counts()
# Out:
# 75     1557
# 73     1452
# 67     1216
# 44     1020
# 79     1012
#        ...
# 112      23
# 19       20
# 111      11
# 17       10
# 22        1
# Name: PRECINCT, Length: 77, dtype: int64

# %%
df['PERP_SEX'].value_counts()
# Out:
# M         15439
# U          1499
# (null)      640
# F           424
# Name: PERP_SEX, dtype: int64

# %%
df['PERP_RACE'].value_counts()
# Out:
# BLACK                             11432
# WHITE HISPANIC                     2341
# UNKNOWN                            1836
# BLACK HISPANIC                     1314
# (null)                              640
# WHITE                               283
# ASIAN / PACIFIC ISLANDER            154
# AMERICAN INDIAN/ALASKAN NATIVE        2
# Name: PERP_RACE, dtype: int64

# %%
df['VIC_AGE_GROUP'].value_counts()
# Out:
# 25-44      12281
# 18-24      10086
# <18         2839
# 45-64       1863
# 65+          181
# UNKNOWN       61
# 1022           1
# Name: VIC_AGE_GROUP, dtype: int64

# %%
df['VIC_SEX'].value_counts()
# Out:
# M    24686
# F     2615
# U       11
# Name: VIC_SEX, dtype: int64

# %%
df['VIC_RACE'].value_counts()
# Out:
# BLACK                             19439
# WHITE HISPANIC                     4049
# BLACK HISPANIC                     2646
# WHITE                               698
# ASIAN / PACIFIC ISLANDER            404
# UNKNOWN                              66
# AMERICAN INDIAN/ALASKAN NATIVE       10
# Name: VIC_RACE, dtype: int64

# %%
dfe = pd.read_csv('penguins.csv')

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
len(dfe)
# Out:
# 344

# %%
dfe.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
dfe.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
dfe.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
dfe['island'].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
dfe['sex'].value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
dfe.body_mass_g.mean()
# Out:
# 4201.754385964912

# %%
dfe.flipper_length_mm.std()
# Out:
# 14.061713679356894

# %%
dfe.flipper_length_mm.min()
# Out:
# 172.0

# %%
dfe.flipper_length_mm.max()
# Out:
# 231.0

# %%
dfe.plot();

# %%
df.plot();

# %%
df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0     228798151  05/27/2021   21:30:00  QUEENS               NaN       105
# 1     137471050  06/27/2014   17:40:00   BRONX               NaN        40
# 2     147998800  11/21/2015   03:56:00  QUEENS               NaN       108
# 3     146837977  10/09/2015   18:30:00   BRONX               NaN        44
# 4      58921844  02/19/2009   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG  ... PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0                    False  ...      NaN       NaN         18-24       M
# ...

# %%
df['PRECINCT'].hist(grid=False);

# %%
df['PRECINCT'].plot(kind='hist', grid=True);

# %%
df.columns
# Out:
# Index(['INCIDENT_KEY', 'OCCUR_DATE', 'OCCUR_TIME', 'BORO', 'LOC_OF_OCCUR_DESC',
#        'PRECINCT', 'JURISDICTION_CODE', 'LOC_CLASSFCTN_DESC', 'LOCATION_DESC',
#        'STATISTICAL_MURDER_FLAG', 'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE',
#        'VIC_AGE_GROUP', 'VIC_SEX', 'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD',
#        'Latitude', 'Longitude', 'Lon_Lat'],
#       dtype='object')

# %%
df_test = df[['INCIDENT_KEY', 'OCCUR_DATE', 'OCCUR_TIME', 'VIC_SEX']]
df_test.head(20)
# Out:
#     INCIDENT_KEY  OCCUR_DATE OCCUR_TIME VIC_SEX
# 0      228798151  05/27/2021   21:30:00       M
# 1      137471050  06/27/2014   17:40:00       M
# 2      147998800  11/21/2015   03:56:00       M
# 3      146837977  10/09/2015   18:30:00       M
# 4       58921844  02/19/2009   22:58:00       M
# 5      219559682  10/21/2020   21:36:00       M
# 6       85295722  06/17/2012   22:47:00       M
# 7       71662474  03/08/2010   19:41:00       M
# 8       83002139  02/05/2012   05:45:00       M
# 9       86437261  08/26/2012   01:10:00       M
# 10      74998200  10/10/2010   03:21:00       M
# 11      74363835  08/29/2010   01:27:00       M
# 12     234756217  10/09/2021   20:17:00       M
# 13      78961869  05/25/2011   21:58:00       M
# 14      53891791  11/09/2008   20:13:00       M
# 15      32914993  07/05/2007   01:27:00       M
# 16      73879554  07/27/2010   02:22:00       M
# 17      87694905  11/14/2012   21:07:00       M
# 18     230311079  07/01/2021   02:44:00       M
# ...

# %%
df[['PRECINCT', 'JURISDICTION_CODE']].plot(kind='hist');

# %%
df[['PRECINCT', 'JURISDICTION_CODE']].plot(kind='hist', subplots=True);

# %%
data = {
    'Name':   ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob'],
    'City':   ['New York', 'Paris', 'London', 'Tokyo', 'Paris'],
    'Age':    [25, 30, 35, 28, 32],
    'Salary': [50000, 60000, 70000, 55000, 65000],
}

df_group = pd.DataFrame(data)
df_group
# Out:
#       Name      City  Age  Salary
# 0    Alice  New York   25   50000
# 1      Bob     Paris   30   60000
# 2  Charlie    London   35   70000
# 3    Alice     Tokyo   28   55000
# 4      Bob     Paris   32   65000

# %%
grouped = df_group.groupby('City')

# %%
average_age = grouped['Age'].mean()
total_salary = grouped['Salary'].mean()

# %%
print(f'Average age in these cities is: \n'
      f'{average_age}')
print('\n')
print(f'Average salary in these cities is: \n'
      f'{total_salary}')
# Out:
# Average age in these cities is:
# City
# London      35.0
# New York    25.0
# Paris       31.0
# Tokyo       28.0
# Name: Age, dtype: float64
#
#
# Average salary in these cities is:
# City
# London      70000.0
# New York    50000.0
# Paris       62500.0
# Tokyo       55000.0
# Name: Salary, dtype: float64

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dfe.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
dfe['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
island = dfe.groupby('island')

# %%
average_mass = island['body_mass_g'].mean()
average_mass
# Out:
# island
# Biscoe       4716.017964
# Dream        3712.903226
# Torgersen    3706.372549
# Name: body_mass_g, dtype: float64

# %%
average_mass = dfe.groupby('island')['body_mass_g'].mean()
average_mass
# Out:
# island
# Biscoe       4716.017964
# Dream        3712.903226
# Torgersen    3706.372549
# Name: body_mass_g, dtype: float64

# %%
dfe.groupby('island')['body_mass_g'].plot(kind='hist', legend=True, alpha=0.75);

# %%
dfe.groupby('island').mean()
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# island
# Biscoe          45.257485      15.874850         209.706587  4716.017964
# Dream           44.167742      18.344355         193.072581  3712.903226
# Torgersen       38.950980      18.429412         191.196078  3706.372549

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
av_species_length = dfe.groupby('species')['bill_length_mm']
av_species_length.plot(kind='hist', legend=True, alpha=0.5);

# %%
av_species_length

# %%
av_species_length = dfe.groupby('species')['bill_length_mm']
av_species_length.plot(kind='kde', legend=True);

# %%
dfe
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
dfe['bill_length_mm'].plot(kind='kde');

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dfe.groupby(['species'])['body_mass_g'].plot(kind='kde', legend=True, alpha=0.5);

# %%
dfe.groupby(['sex'])['body_mass_g'].plot(kind='kde', legend=True);

# %%
#dfe['body_mass_g'].plot(kind='kde');
#dfe.groupby('species')['body_mass_g'].plot(kind='kde', legend=True);
#dfe.groupby('sex')['body_mass_g'].plot(kind='kde', legend=True);
dfe.groupby(['sex','species'])['body_mass_g'].plot(kind='kde', legend=True);

# %%
df.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME    BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# 0     228798151  05/27/2021   21:30:00  QUEENS               NaN       105
# 1     137471050  06/27/2014   17:40:00   BRONX               NaN        40
# 2     147998800  11/21/2015   03:56:00  QUEENS               NaN       108
# 3     146837977  10/09/2015   18:30:00   BRONX               NaN        44
# 4      58921844  02/19/2009   22:58:00   BRONX               NaN        47
#
#    JURISDICTION_CODE LOC_CLASSFCTN_DESC LOCATION_DESC  \
# 0                0.0                NaN           NaN
# 1                0.0                NaN           NaN
# 2                0.0                NaN           NaN
# 3                0.0                NaN           NaN
# 4                0.0                NaN           NaN
#
#    STATISTICAL_MURDER_FLAG  ... PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0                    False  ...      NaN       NaN         18-24       M
# ...

# %%
df.BORO.value_counts().plot(figsize=(3, 2), kind='bar');

# %%
df['BORO'].value_counts().plot(figsize=(3, 2), kind='bar');

# %%
df.BORO.value_counts().plot(figsize=(3, 2), kind='barh');

# %%
df['BORO'].value_counts().plot(figsize=(3, 2), kind='barh');

# %%
df['VIC_RACE'].value_counts().plot(figsize=(2, 2), kind='barh');

# %%
df.VIC_AGE_GROUP.value_counts().plot(figsize=(2,2), kind='barh');

# %%
dfe
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
dfe.plot(x='flipper_length_mm', y='body_mass_g', kind='scatter');

# %%
dfe
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
dfe.groupby(['island', 'sex']).sum()['body_mass_g'].unstack('island').plot(kind='bar', stacked=True);

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dfe['species'].value_counts().plot(kind='pie');

# %%
df['BORO'].value_counts().plot(kind='pie');

# %%
dfe['species'].value_counts().plot(figsize=(3, 2), kind='bar');

# %%
species_sex = dfe.groupby(['species', 'sex']).mean()['body_mass_g'].unstack('sex')

species_sex.plot(kind='bar');

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

dfe[dfe.species=='Adelie'].plot(
    x='body_mass_g', y='bill_length_mm', kind='scatter', ax=ax, c='r', label='Adelie')
dfe[dfe.species=='Gentoo'].plot(
    x='body_mass_g', y='bill_length_mm', kind='scatter', ax=ax, c='b', label='Gentoo')
dfe[dfe.species=='Chinstrap'].plot(
    x='body_mass_g', y='bill_length_mm', kind='scatter', ax=ax, c='g', label='Chinstrap')

ax.set_title('Relationship between bill length and mass')
ax.set_xlabel('Mass in g')
ax.set_ylabel('Bill length in mm')

plt.show()

# %%
fig, ax = plt.subplots()

dfe[dfe.species=='Adelie'].plot(
    x='bill_depth_mm', y='bill_length_mm', kind='scatter', ax=ax, c='r', label='Adelie')
dfe[dfe.species=='Gentoo'].plot(
    x='bill_depth_mm', y='bill_length_mm', kind='scatter', ax=ax, c='b', label='Gentoo')
dfe[dfe.species=='Chinstrap'].plot(
    x='bill_depth_mm', y='bill_length_mm', kind='scatter', ax=ax, c='g', label='Chinstrap')

ax.set_title('Relationship between bill depth and bill length')
ax.set_xlabel('Bill depth in mm')
ax.set_ylabel('Bill length in mm')

plt.show()

# %%
fig, ax = plt.subplots()

dfe[dfe.species=='Adelie'].plot(
    x='body_mass_g', y='bill_depth_mm', kind='scatter', ax=ax, c='r', label='Adelie')
dfe[dfe.species=='Gentoo'].plot(
    x='body_mass_g', y='bill_depth_mm', kind='scatter', ax=ax, c='b', label='Gentoo')
dfe[dfe.species=='Chinstrap'].plot(
    x='body_mass_g', y='bill_depth_mm', kind='scatter', ax=ax, c='g', label='Chinstrap')

ax.set_title('Relationship between bill depth and mass')
ax.set_xlabel('Mass in g')
ax.set_ylabel('Bill depth in mm')

plt.show()

# %%
fig, ax = plt.subplots()

dfe[dfe.species=='Adelie'].plot(
    x='flipper_length_mm', y='body_mass_g', kind='scatter', ax=ax, c='r', label='Adelie')
dfe[dfe.species=='Gentoo'].plot(
    x='flipper_length_mm', y='body_mass_g', kind='scatter', ax=ax, c='b', label='Gentoo')
dfe[dfe.species=='Chinstrap'].plot(
    x='flipper_length_mm', y='body_mass_g', kind='scatter', ax=ax, c='g', label='Chinstrap')

ax.set_title('Relationship between flipper length and mass')
ax.set_xlabel('Flipper length in mm')
ax.set_ylabel('Mass in g')

plt.show()

# %%
dfe.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
fig, ax = plt.subplots()

dfe[dfe.island=='Biscoe'].plot(
    x='body_mass_g', y='bill_length_mm', kind='scatter', ax=ax, c='r', label='Biscoe island')
dfe[dfe.island=='Dream'].plot(
    x='body_mass_g', y='bill_length_mm', kind='scatter', ax=ax, c='b', label='Dream island')
dfe[dfe.island=='Torgersen'].plot(
    x='body_mass_g', y='bill_length_mm', kind='scatter', ax=ax, c='g', label='Torgersen island')

ax.set_title('Relationship between bill length and mass')
ax.set_xlabel('Mass in g')
ax.set_ylabel('Bill length in mm')

plt.show()

# %%
dfe.island.value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df_island_index = pd.read_csv('NYPD_Shooting_Incident_Data__Historic_.csv', index_col=1, parse_dates=True)
df_island_index
# Out:
#             INCIDENT_KEY OCCUR_TIME       BORO LOC_OF_OCCUR_DESC  PRECINCT  \
# OCCUR_DATE
# 2021-05-27     228798151   21:30:00     QUEENS               NaN       105
# 2014-06-27     137471050   17:40:00      BRONX               NaN        40
# 2015-11-21     147998800   03:56:00     QUEENS               NaN       108
# 2015-10-09     146837977   18:30:00      BRONX               NaN        44
# 2009-02-19      58921844   22:58:00      BRONX               NaN        47
# ...                  ...        ...        ...               ...       ...
# 2022-05-14     245029823   03:02:00      BRONX           OUTSIDE        48
# 2022-01-22     239583450   13:15:00  MANHATTAN           OUTSIDE        30
# 2022-06-18     246825728   03:29:00  MANHATTAN           OUTSIDE        32
# 2022-06-19     246876579   20:08:00      BRONX            INSIDE        46
# 2022-01-28     239861542   18:14:00      BRONX           OUTSIDE        45
#
# ...

# %%
df[['PRECINCT', 'JURISDICTION_CODE']].plot(kind='hist', subplots=True, layout=(1,2), figsize=(15, 4));

# %%
df[['PRECINCT', 'JURISDICTION_CODE']].plot(kind='area', subplots=True, layout=(1,2), figsize=(15, 4));
