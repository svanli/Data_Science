# %% [markdown]
# # Notes (parts 05–06)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %% [markdown]
# # 05. How to customize your plots

# %%
df = pd.read_csv('mpg.csv')

# %%
dfe = pd.read_csv('penguins.csv')

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(7, 4), constrained_layout=True)

ax4.remove()

# Matplotlib
ax1.hist(dfe['body_mass_g'])
ax1.set_xlabel('Body mass in g')
ax1.set_ylabel('Frequency')

# pandas
dfe['body_mass_g'].plot(kind='hist', ax=ax2)
ax2.set_xlabel('Body mass in g')

# Seaborn
sns.histplot(data=dfe, x='body_mass_g', kde=True, ax=ax3)
ax3.set_xlabel('Body mass in g')
ax3.set_ylabel('Frequency')

# Title
fig.suptitle('Distribution of body mass', fontsize=16)

plt.show()

# %%
fig, axs = plt.subplot_mosaic("""
    ABB
    CBB
    """, figsize=(7, 4), layout='constrained')

# Matplotlib
axs['A'].hist(dfe['body_mass_g'])
axs['A'].set_xlabel('Body mass in g')
axs['A'].set_ylabel('Frequency')

# pandas
dfe['body_mass_g'].plot(kind='hist', ax=axs['B'])
#axs['B'].set_xlabel('Body mass in g')

# Seaborn
sns.histplot(data=dfe, x='body_mass_g', kde=True, ax=axs['C'])
axs['C'].set_xlabel('Body mass in g')
axs['C'].set_ylabel('Frequency')

# Title
fig.suptitle('Distribution of body mass', fontsize=16)

plt.show()

# %%
dfe.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dfe.groupby('species')['body_mass_g'].mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
fig, ax = plt.subplots()

sns.barplot(data=dfe, x='species', y='body_mass_g', ax=ax)

ax.set_title('Body mass per species with averages')

ax.annotate(text='average\n3 701', xy=(0, 4500),
            horizontalalignment='center', verticalalignment='bottom', #color='b',
            bbox=dict(boxstyle='round,pad=0.1', fc='w', lw=7))

ax.annotate(text='average\n3 733', xy=(1, 4500),
            horizontalalignment='center', verticalalignment='bottom',
            bbox=dict(boxstyle='round,pad=0.1', fc='w', lw=7))

ax.annotate('Maximum', xy=(2, 6500), xytext=(2, 8000),
            horizontalalignment='center', verticalalignment='bottom',
            bbox=dict(boxstyle='round,pad=0.1', fc='w', lw=7),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate(text='average\n5 076', xy=(2, 5500),
            horizontalalignment='center', verticalalignment='bottom',
            bbox=dict(boxstyle='round,pad=0.1', fc='w', lw=7))

ax.set_xlim(-1, 3)
ax.set_ylim(2000, 9000)

ax.set_xlabel(None)
ax.set_ylabel('Body mass in g')


plt.show()

# %%
fig, ax = plt.subplots()

sns.barplot(data=df, x='origin', y='mpg', ax=ax);

ax.annotate(
    text='mean=20.08', 
    xy=(0, 16), 
    horizontalalignment='center',
    verticalalignment='bottom',
    color='b',
    bbox=dict(boxstyle="round,pad=0.3", fc="w", ec="w", lw=2)
);

ax.annotate(
    text='mean=30.45',
    xy=(1, 26), 
    horizontalalignment='center',
    verticalalignment='bottom',
    color='b',
    bbox=dict(boxstyle="round,pad=0.3", fc="w", ec="w", lw=2)
);

ax.annotate(
    text='mean=27.89',
    xy=(2, 23), 
    horizontalalignment='center',
    verticalalignment='bottom',
    color='b',
    bbox=dict(boxstyle="round,pad=0.3", fc="w", ec="w", lw=2)
);

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # 06. Final project

# %% [markdown]
# 1. When do people see UFOs?<br>
# a. What is the yearly/monthly/daily trend of UFO sightings?<br>
# b. Which year/month of the year/day of the month has the highest number of UFO sightings?
#
# 2. Where do people see UFOs?<br>
# a. Which country has the highest number of UFO sightings?
# 3. What are the trends of UFO sightings over time?<br>
# a. Are there overall trend differences by country?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('scrubbed.csv', low_memory=False)

# %%
df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
# df = df.rename(columns={'shape': 'UFO shape', 'comments': 'My comments'})

# %%
# df = df.rename(columns={'UFO shape': 'shape', 'My comments': 'comments'})

# %%
df['country'].value_counts()
# Out:
# us    65114
# ca     3000
# gb     1905
# au      538
# de      105
# Name: country, dtype: int64

# %%
df.groupby('country')['datetime'].count()
# Out:
# country
# au      538
# ca     3000
# de      105
# gb     1905
# us    65114
# Name: datetime, dtype: int64

# %%
df[df['city']=='edna']
# Out:
#                datetime  city state country    shape duration (seconds)  \
# 3      10/10/1956 21:00  edna    tx      us   circle                 20
# 12866  11/25/1985 00:00  edna    tx      us  unknown                240
# 43242   5/19/2012 21:00  edna    tx      us    other               3600
#
#       duration (hours/min)                                           comments  \
# 3                 1/2 hour  My older brother and twin sister were leaving ...
# 12866            4 minutes  nothing on military or commercialcould move th...
# 43242               1 hour  Multiple vertical UFO&#39s spotted over Edna&#...
#
#       date posted    latitude  longitude
# 3       1/17/2004  28.9783333  -96.645833
# 12866   1/21/2008  28.9783333  -96.645833
# 43242   5/29/2012  28.9783333  -96.645833

# %%
df[df['duration (seconds)'].str.contains('`')]
# Out:
#               datetime               city state country   shape  \
# 27822   2/2/2000 19:33              bouse    az      us     NaN
# 35692  4/10/2005 22:52         santa cruz    ca      us     NaN
# 58591  7/21/2006 13:00  ibague (colombia)   NaN     NaN  circle
#
#       duration (seconds) duration (hours/min)  \
# 27822                 2`   each a few seconds
# 35692                 8`        eight seconds
# 58591               0.5`          1/2 segundo
#
#                                                 comments date posted  \
# 27822  Driving through Plomosa Pass towards Bouse Loo...   2/16/2000
# 35692  2 red lights moving together and apart with a ...   4/16/2005
# 58591  Viajaba a 27.000 pies en un avion comercial ve...  10/30/2006
#
#          latitude  longitude
# 27822  33.9325000 -114.005000
# 35692  36.9741667 -122.029722
# 58591    4.440663  -75.244141
